# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt

print("CWD:", os.getcwd())

project_root = os.path.abspath("/Users/amelia/DAT5501-project002")
print("Project root:", project_root)

if project_root not in sys.path:
    sys.path.append(project_root)

print("sys.path entires: ", sys.path[-3:])

from src.ingestion.demand import load_weekly_demand
from src.models.baseline import seasonal_naive, rolling_average, time_regression
from src.evaluation.metrics import compute_errors
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       3 import matplotlib.pyplot as plt
#       5 sys.path.append(".")
# ----> 7 from src.ingestion.demand import load_weekly_demand
#       8 from src.models.baselines import seasonal_naive, rolling_average, time_regression
#       9 from src.evaluation.metrics import compute_errors
#
# ModuleNotFoundError: No module named 'src'

# %%
print(os.getcwd())
print("src" in os.listdir())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       3 import matplotlib.pyplot as plt
#       5 sys.path.append(".")
# ----> 7 from src.ingestion.demand import load_weekly_demand
#       8 from src.models.baselines import seasonal_naive, rolling_average, time_regression
#       9 from src.evaluation.metrics import compute_errors
#
# ModuleNotFoundError: No module named 'src'
